# %%
# !pip install ccxt
# Out:
# Requirement already satisfied: ccxt in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (1.18.1220)
# Requirement already satisfied: yarl==1.1.0; python_version >= "3.5.2" in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from ccxt) (1.1.0)
# Requirement already satisfied: setuptools>=38.5.1 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from ccxt) (41.2.0)
# Requirement already satisfied: aiohttp>=3.0.1; python_version >= "3.5.2" in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from ccxt) (3.6.2)
# Requirement already satisfied: aiodns==1.1.1; python_version >= "3.5.2" in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from ccxt) (1.1.1)
# Requirement already satisfied: cryptography>=2.6.1 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from ccxt) (2.8)
# Requirement already satisfied: certifi>=2018.1.18 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from ccxt) (2019.11.28)
# Requirement already satisfied: requests>=2.18.4 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from ccxt) (2.22.0)
# Requirement already satisfied: multidict>=4.0 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from yarl==1.1.0; python_version >= "3.5.2"->ccxt) (4.7.4)
# Requirement already satisfied: idna>=2.0 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from yarl==1.1.0; python_version >= "3.5.2"->ccxt) (2.8)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from aiohttp>=3.0.1; python_version >= "3.5.2"->ccxt) (3.0.1)
# Requirement already satisfied: chardet<4.0,>=2.0 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from aiohttp>=3.0.1; python_version >= "3.5.2"->ccxt) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from aiohttp>=3.0.1; python_version >= "3.5.2"->ccxt) (19.3.0)
# Requirement already satisfied: pycares>=1.0.0 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from aiodns==1.1.1; python_version >= "3.5.2"->ccxt) (3.1.1)
# Requirement already satisfied: six>=1.4.1 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from cryptography>=2.6.1->ccxt) (1.13.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from cryptography>=2.6.1->ccxt) (1.13.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from requests>=2.18.4->ccxt) (1.25.7)
# Requirement already satisfied: pycparser in c:\program files (x86)\microsoft visual studio\shared\python37_64\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.6.1->ccxt) (2.19)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import ccxt

binance = ccxt.binance ()
binance.load_markets ()

print ('binance: %d markets Loaded!' % len (binance.markets))
# Out:
# binance: 770 markets Loaded!

# %%
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt 

plt.style.use ('seaborn-white')
plt.rcParams["figure.figsize"] = [15,6]

# %%
import pandas as pd
from datetime import datetime

pair = 'BTC/USDT'

ohlcv = binance.fetch_ohlcv (pair, '1d')

prices = [x[4] for x in ohlcv]

dates = [datetime.fromtimestamp (x[0] // 1000) for x in ohlcv]

data = pd.Series (prices, index=dates)

data.plot ()
